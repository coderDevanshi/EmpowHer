# %%
import json
import csv

def clean_json_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    
    # Remove any extra characters outside the JSON array
    start_index = content.find('[')
    end_index = content.rfind(']') + 1
    cleaned_content = content[start_index:end_index]
    
    return cleaned_content

def extract_all_entries(file_path, required_fields):
    # Clean the JSON file content
    cleaned_content = clean_json_file(file_path)
    
    # Load the cleaned JSON data
    data = json.loads(cleaned_content)
    
    # Extract the specified fields for all entries
    extracted_data = [{field: entry.get(field) for field in required_fields} for entry in data]
    
    return extracted_data

def save_to_csv(data, csv_file_path):
    # Open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=data[0].keys())
        
        # Write the header
        writer.writeheader()
        
        # Write the data
        for row in data:
            writer.writerow(row)

# Define the file path and required fields
file_path = 'data1.json'
required_fields = [
    "job_id", "job_title", "htidocid", "gl", "hl", "fc", "fcv", "fc_id",
    "apply_link", "apply_link_title", "apply_options", "salaries", "ratings"
]

# Extract all entries with the required fields
extracted_data = extract_all_entries(file_path, required_fields)

# Define the CSV file path
csv_file_path = 'all_entries.csv'

# Save the extracted data to a CSV file
save_to_csv(extracted_data, csv_file_path)

print(f"Data has been saved to {csv_file_path}")
# Out:
# Data has been saved to all_entries.csv

# %%
import pandas as pd
df = pd.read_csv('all_entries.csv')

# %%
df.head()
# Out:
#                                               job_id  job_title  htidocid  gl  \
# 0  eyJqb2JfdGl0bGUiOiJGbGV4aWJsZSBQYXJ0LVRpbWUgSm...        NaN       NaN NaN
# 1  eyJqb2JfdGl0bGUiOiJFeHRlcm5hbCBFdmVudHMgSW50ZX...        NaN       NaN NaN
# 2  eyJqb2JfdGl0bGUiOiJEaXJlY3RvciBvZiBEZXZlbG9wbW...        NaN       NaN NaN
# 3  eyJqb2JfdGl0bGUiOiJHZW5kZXIgRXF1YWxpdHkgYW5kIF...        NaN       NaN NaN
# 4  eyJqb2JfdGl0bGUiOiJXb21lbidzIEhlYWx0aCBDbGluaW...        NaN       NaN NaN
#
#    hl  fc  fcv  fc_id  apply_link  apply_link_title  \
# 0 NaN NaN  NaN    NaN         NaN               NaN
# 1 NaN NaN  NaN    NaN         NaN               NaN
# 2 NaN NaN  NaN    NaN         NaN               NaN
# 3 NaN NaN  NaN    NaN         NaN               NaN
# 4 NaN NaN  NaN    NaN         NaN               NaN
#
#                                        apply_options  \
# 0  [{'title': 'Apply directly on Upwork', 'link':...
# 1  [{'title': 'Apply on Women For Women Internati...
# 2  [{'title': 'Apply on LinkedIn', 'link': 'https...
# 3  [{'title': 'Apply on 11 Academia Networks', 'l...
# 4  [{'title': 'Apply on Wholesome Hiring', 'link'...
#
#                                             salaries  \
# 0                                                NaN
# 1  [{'job_title': 'External Relations Intern', 'l...
# 2  [{'job_title': 'Director of Development', 'lin...
# 3                                                NaN
# 4                                                NaN
#
#                                              ratings
# 0  [{'link': 'https://www.glassdoor.co.in/Reviews...
# 1  [{'link': 'https://www.glassdoor.co.in/Reviews...
# 2                                                NaN
# 3  [{'link': 'https://www.indeed.com/cmp/Food-and...
# 4  [{'link': 'https://www.indeed.com/cmp/Incredib...

# %%
#only keep salaries column
df = df[['salaries']]

# %%
#save 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salaries  39 non-null     object
# dtypes: object(1)
# memory usage: 772.0+ bytes

# %%
df.dropna(inplace=True)

# %%
df.head(10)
# Out:
#                                              salaries
# 1   [{'job_title': 'External Relations Intern', 'l...
# 2   [{'job_title': 'Director of Development', 'lin...
# 5   [{'job_title': "Women's Health Manager", 'link...
# 7   [{'job_title': 'Director, Marketing', 'link': ...
# 11  [{'job_title': 'Mechanic', 'link': 'https://ww...
# 15  [{'job_title': 'sales leader', 'link': 'https:...
# 18  [{'job_title': 'Cook', 'link': 'https://www.in...
# 20  [{'job_title': 'Contract Ux Ui Designer', 'lin...
# 22  [{'job_title': 'Content Writer Intern', 'link'...
# 24  [{'job_title': 'Financial Analyst Intern', 'li...

# %%
#save to csv
df.to_csv('salaries.csv',index=False)

# %%
with open("salaries.csv", "r") as file:
  lines = file.readlines()
  for line in lines:
    print(type(line), line)
# Out:
# <class 'str'> salaries
#
# <class 'str'> "[{'job_title': 'External Relations Intern', 'link': 'https://www.glassdoor.com/Salary/International-Institute-for-Strategic-Studies-External-Relations-Intern-Salaries-E962016_D_KO46,71.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 40000, 'salary_to': 60000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Director of Development', 'link': 'https://www.glassdoor.com/Salaries/new-york-city-director-of-development-salary-SRCH_IL.0,13_IM615_KO14,37.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 1.5, 'salary_to': 2.6, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Director of Development, Non-Profit Organization', 'link': 'https://www.salary.com/research/salary/alternate/director-of-development-non-profit-organization-salary/new-york-ny?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 1.1, 'salary_to': 2.7, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Director of Development, Non-Profit Organization', 'link': 'https://www.payscale.com/research/US/Job=Director_of_Development%2C_Non-Profit_Organization/Salary/05b19c61/New-York-NY?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 58000, 'salary_to': 1.4, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': ""Women's Health Manager"", 'link': ""https://www.indeed.com/cmp/Hire-Partnership,-LLC/salaries/Women's-Health-Manager/Massachusetts?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic"", 'source': 'Indeed', 'salary_from': 55000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Womens Health', 'link': 'https://www.ziprecruiter.com/Salaries/Womens-Health-Salary--in-Massachusetts?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 1.2, 'salary_to': 3.8, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'OB/GYN Physician', 'link': 'https://www.salary.com/research/salary/alternate/ob-gyn-physician-salary/ma?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 2.6, 'salary_to': 4.8, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Director, Marketing', 'link': 'https://www.salary.com/research/company/women-s-golf-association-of-northern-california/director-marketing-salary?cjid=10856535&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 1.6, 'salary_to': 2, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Mechanic', 'link': 'https://www.indeed.com/cmp/Kellanova-1/salaries/Mechanic/Blue-Anchor-NJ?period=daily&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 190, 'salary_to': 230, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'sales leader', 'link': 'https://www.talent.com/salary?job=sales+leader&location=livermore&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Talent.com', 'salary_from': 47000, 'salary_to': 75000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Sales Associate', 'link': 'https://www.indeed.com/cmp/Janie-and-Jack/salaries/Sales-Associate/Livermore-CA?period=weekly&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 350, 'salary_to': 1100, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Sales Associate', 'link': 'https://www.ihiresalespeople.com/t-sales-associate-s-california-c-discovery-bay-jobs.html?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'IHireSalesPeople', 'salary_from': 35000, 'salary_to': 58000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Cook', 'link': 'https://www.indeed.com/cmp/Geisinger/salaries/Cook/Muncy%2C+PA?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 19, 'salary_to': 22, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Geisinger'}]"
#
# <class 'str'> "[{'job_title': 'Contract Ux Ui Designer', 'link': 'https://www.ziprecruiter.com/Salaries/Contract-Ux-Ui-Designer-Salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 33, 'salary_to': 76, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'contract ux designer', 'link': 'https://www.talent.com/salary?job=contract+ux+designer&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Talent.com', 'salary_from': 78000, 'salary_to': 1.6, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'User Experience Lead', 'link': 'https://www.seek.com.au/career-advice/role/user-experience-lead/salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'SEEK', 'salary_from': 1.2, 'salary_to': 1.8, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Content Writer Intern', 'link': 'https://www.ziprecruiter.com/Salaries/Content-Writer-Intern-Salary-in-New-York-City,NY?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 21, 'salary_to': 98, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'copywriter intern', 'link': 'https://www.talent.com/salary?job=copywriter+intern&location=new+york&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Talent.com', 'salary_from': 32000, 'salary_to': 48000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Public Relations Intern', 'link': 'https://www.salary.com/research/company/chasen-creative-media/public-relations-intern-salary?cjid=18088325&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 54000, 'salary_to': 69000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Financial Analyst Intern', 'link': 'https://www.indeed.com/cmp/Wells-Fargo/salaries/Financial-Analyst-Intern/Charlotte-NC?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 14, 'salary_to': 45, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Wells Fargo'}]"
#
# <class 'str'> "[{'job_title': 'Internship Graphic Designer', 'link': 'https://www.ziprecruiter.com/Salaries/Internship-Graphic-Designer-Salary-in-Pittsburgh,PA?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 11, 'salary_to': 21, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Graphic Design Intern', 'link': 'https://www.indeed.com/cmp/Duolingo/salaries/Graphic-Design-Intern/Pittsburgh-PA?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 18, 'salary_to': 21, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Graphic Artist Intern', 'link': 'https://www.salary.com/research/salary/listing/graphic-artist-intern-salary/new-brighton-pa?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 46000, 'salary_to': 75000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Business Development Intern', 'link': 'https://www.glassdoor.co.in/Salaries/business-development-intern-salary-SRCH_KO0,27.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 7600, 'salary_to': 1.4, 'salary_periodicity': 'month', 'salary_period': 'month', 'based_on': 'Based on local employers'}, {'job_title': 'Business Development Intern Salary in India', 'link': 'https://www.ambitionbox.com/profile/business-development-intern-salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'AmbitionBox', 'salary_from': 1, 'salary_to': 5, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Business Development Intern', 'link': 'https://in.indeed.com/career/business-development-intern/salaries/Maharashtra?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 8100, 'salary_to': 31000, 'salary_periodicity': 'month', 'salary_period': 'month', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'User Experience Design Intern', 'link': 'https://www.indeed.com/cmp/Appetizer-Mobile-LLC-1/salaries/User-Experience-Design-Intern/New-York-NY?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 23, 'salary_to': 28, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Design Intern', 'link': 'https://www.ziprecruiter.com/Salaries/Design-Intern-Salary-in-New-York-City,NY?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 13, 'salary_to': 32, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Design Intern', 'link': 'https://www.glassdoor.com/Salaries/new-york-city-design-intern-salary-SRCH_IL.0,13_IM615_KO14,27.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 49000, 'salary_to': 76000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Independent Contractor Video Editor', 'link': 'https://www.ziprecruiter.com/Salaries/Independent-Contractor-Video-Editor-Salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 18, 'salary_to': 49, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Retail Sales Associate', 'link': 'https://www.indeed.com/cmp/Autozone/salaries/Retail-Sales-Associate/Port-Saint-Lucie-FL?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 16, 'salary_to': 20, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Retail Sales Associate', 'link': 'https://www.glassdoor.com/Salaries/port-st-lucie-fl-united-states-retail-sales-associate-salary-SRCH_IL.0,30_IM697_KO31,53.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 51000, 'salary_to': 90000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'sales associate', 'link': 'https://www.talent.com/salary?job=sales+associate&location=port+saint+lucie,+fl&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Talent.com', 'salary_from': 23000, 'salary_to': 70000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'merchandiser', 'link': 'https://www.talent.com/salary?job=merchandiser&location=mcalester,+ok&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Talent.com', 'salary_from': 23000, 'salary_to': 40000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Merchandising Associate', 'link': 'https://www.indeed.com/cmp/The-TJX-Companies,-Inc./salaries/Merchandising-Associate/McAlester-OK?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 17, 'salary_to': 20, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'accounting administrative assistant', 'link': 'https://www.talent.com/salary?job=accounting+administrative+assistant&location=elgin&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Talent.com', 'salary_from': 37000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Accounts Receivable Administrative Assistant', 'link': 'https://www.salary.com/research/salary/offering/accounts-receivable-administrative-assistant-salary/elgin-il?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 47000, 'salary_to': 58000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Customer Service Representative', 'link': 'https://www.indeed.com/cmp/New-York-Sports-Club-and-Our-Family-of-Brands-1/salaries/Customer-Service-Representative/New-York-NY?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 15, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Customer Service Advisor', 'link': 'https://www.glassdoor.com/Salary/Foundever-Customer-Service-Advisor-New-York-City-Salaries-EJI_IE11480.0,9_KO10,34_IL.35,48_IM615.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 42000, 'salary_to': 66000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Customer Service Representative', 'link': 'https://www.ihire.com/t-customer-service-representative-s-new-york-c-astoria-jobs.html?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'IHire', 'salary_from': 32000, 'salary_to': 73000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Data Entry Administrative Assistant', 'link': 'https://www.salary.com/research/salary/opening/data-entry-administrative-assistant-salary/vernal-ut?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 36000, 'salary_to': 56000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Mobile Application Tester', 'link': 'https://www.totaljobs.com/salary-checker/average-mobile-application-tester-salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Totaljobs', 'salary_from': 27000, 'salary_currency': '£', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Mobile Applications Developer', 'link': 'https://www.salary.com/research/salary/benchmark/mobile-applications-developer-ii-salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 81000, 'salary_to': 1.3, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Sr. Mobile App Developer', 'link': 'https://www.ambitionbox.com/salaries/optum-salaries/sr-dot-mobile-app-developer?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'AmbitionBox', 'salary_from': 6, 'salary_to': 10, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Independent Contractor Video Editor', 'link': 'https://www.ziprecruiter.com/Salaries/Independent-Contractor-Video-Editor-Salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 18, 'salary_to': 49, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Video Editor', 'link': 'https://www.indeed.com/cmp/Russell-Tobin-&-Associates---Contract-to-Hire/salaries/Video-Editor/Cupertino-CA?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 54, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Freelance Writer', 'link': 'https://www.ziprecruiter.com/Salaries/Freelance-Writer-Salary-in-New-York-City,NY?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 19, 'salary_to': 34, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Freelance Writer', 'link': 'https://www.glassdoor.co.in/Salary/Freelance-Freelance-Writer-New-York-City-Ny-United-States-Salaries-EJI_IE1130527.0,9_KO10,26_IL.27,57_IM615.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 53000, 'salary_to': 97000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Freelance Content Writer', 'link': 'https://www.salary.com/research/salary/recruiting/freelance-content-writer-salary/new-york-ny?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 55000, 'salary_to': 68000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Freelance Graphic Designer', 'link': 'https://www.ziprecruiter.com/Salaries/Freelance-Graphic-Designer-Salary-in-Texas-City,TX?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 20, 'salary_to': 41, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Graphic Designer', 'link': 'https://www.indeed.com/cmp/South-Texas-College/salaries/Graphic-Designer?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 16000, 'salary_to': 49000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Freelance Content Creator', 'link': 'https://www.ziprecruiter.com/Salaries/Freelance-Content-Creator-Salary-in-New-York-City,NY?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 80000, 'salary_to': 1.4, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Content Creator', 'link': 'https://www.glassdoor.com/Salaries/new-york-city-content-creator-salary-SRCH_IL.0,13_IM615_KO14,29.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 47000, 'salary_to': 85000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'SERVICE AGREEMENT SPECIALIST', 'link': 'https://www.glassdoor.com/Salaries/united-kingdom-service-agreement-specialist-salary-SRCH_IL.0,14_KO15,43.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 65000, 'salary_to': 1.1, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Service Contract Administrator', 'link': 'https://www.ziprecruiter.com/Salaries/Service-Contract-Administrator-Salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 46000, 'salary_to': 1, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Service Contract Administrator', 'link': 'https://www.salary.com/research/salary/benchmark/service-contract-administrator-salary?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 52000, 'salary_to': 90000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Freelance Video Editor', 'link': 'https://www.ziprecruiter.com/Salaries/Freelance-Video-Editor-Salary-in-Seattle,WA?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'ZipRecruiter', 'salary_from': 20, 'salary_to': 55, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Freelance Video Editor', 'link': 'https://www.glassdoor.com/Salaries/seattle-wa-freelance-video-editor-salary-SRCH_IL.0,10_IC1150505_KO11,33.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 51000, 'salary_to': 83000, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Freelance Video Editor', 'link': 'https://www.salary.com/research/salary/posting/freelance-video-editor-salary/seattle-wa?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Salary.com', 'salary_from': 53000, 'salary_to': 1.2, 'salary_currency': '$', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Presenter', 'link': 'https://www.indeed.com/cmp/Freelancer.com/salaries/Presenter?period=daily&utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 170, 'salary_to': 200, 'salary_currency': '$', 'salary_periodicity': 'hour', 'salary_period': 'hour', 'based_on': 'Based on local employers'}, {'job_title': 'Freelance Reporter', 'link': 'https://www.glassdoor.co.uk/Salaries/freelance-reporter-salary-SRCH_KO0,18.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 19000, 'salary_to': 51000, 'salary_currency': '£', 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Software Engineer', 'link': 'https://www.payscale.com/research/IN/Job=Software_Engineer/Salary/2a0a9605/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 3.6, 'salary_to': 22, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Software Engineer', 'link': 'https://in.indeed.com/career/software-engineer/salaries/Kengeri-Satellite-Town--Karnataka?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 3.4, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Software developer', 'link': 'https://in.jooble.org/salary/software-developer/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Jooble', 'salary_from': 4, 'salary_to': 16, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Test Analyst', 'link': 'https://www.payscale.com/research/IN/Job=Test_Analyst/Salary/4a0ce589/Bangalore-System-Testing?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 3.8, 'salary_to': 11, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Sr.test analyst', 'link': 'https://in.jooble.org/salary/sr.test-analyst/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Jooble', 'salary_from': 4.2, 'salary_to': 21, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Quality Assurance Analyst', 'link': 'https://in.indeed.com/career/quality-assurance-analyst/salaries/Jayanagar-7th-Block--Karnataka?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 3.1, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Data Analyst', 'link': 'https://in.indeed.com/career/data-analyst/salaries/Muneshwara-Block--Karnataka?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 2.7, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Data Analyst', 'link': 'https://www.payscale.com/research/IN/Job=Data_Analyst/Salary/97eb3643/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 3, 'salary_to': 13, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Software Developer', 'link': 'https://www.payscale.com/research/IN/Job=Software_Developer/Salary/887af8b5/Hewlett-Packard-Enterprise-Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 3.8, 'salary_to': 9, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Hewlett Packard Enterprise'}, {'job_title': 'Software Engineer', 'link': 'https://in.indeed.com/career/software-engineer/salaries/Jayanagar-2nd-Block--Karnataka?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 3.7, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Sr. network development engineer', 'link': 'https://in.jooble.org/salary/sr.-network-development-engineer/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Jooble', 'salary_from': 1.7, 'salary_to': 15, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Graduate engineer trainee electrical', 'link': 'https://in.jooble.org/salary/graduate-engineer-trainee-electrical/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Jooble', 'salary_from': 4.4, 'salary_to': 4.7, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Research Scientist', 'link': 'https://www.payscale.com/research/IN/Job=Research_Scientist/Salary/e6d895a6/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 3.9, 'salary_to': 39, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Quality Analyst', 'link': 'https://www.payscale.com/research/IN/Job=Quality_Analyst/Salary/6c3d3741/Bangalore-Selenium-Automated-Test-Tool?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 3.9, 'salary_to': 10, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Senior test analyst test lead', 'link': 'https://in.jooble.org/salary/senior-test-analyst-test-lead/Bangalore?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Jooble', 'salary_from': 4.5, 'salary_to': 13, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Legal Operations Specialist', 'link': 'https://www.glassdoor.com/Salaries/gurgaon-haryana-legal-operations-specialist-salary-SRCH_IL.0,15_IC2921225_KO16,43.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 5.4, 'salary_to': 5.8, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Software Engineer', 'link': 'https://www.payscale.com/research/IN/Job=Software_Engineer/Salary/dcf0adcc/Gurgaon?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 4, 'salary_to': 20, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Senior Software Engineer', 'link': 'https://www.glassdoor.com/Salaries/gurgaon-senior-software-engineer-salary-SRCH_IL.0,7_IC2921225_KO8,32.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 13, 'salary_to': 28, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Computer Engineer', 'link': 'https://in.indeed.com/career/computer-engineer/salaries/Manesar--Haryana?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Indeed', 'salary_from': 24000, 'salary_periodicity': 'month', 'salary_period': 'month', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Business Development Executive', 'link': 'https://www.payscale.com/research/IN/Job=Business_Development_Executive/Salary/8bfa759c/Gurgaon?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 1.7, 'salary_to': 11, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Business Development Executive', 'link': 'https://www.glassdoor.com/Salaries/business-development-executive-salary-SRCH_IC2921225_KO0,30.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 3.2, 'salary_to': 12, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Business development sales executive', 'link': 'https://in.jooble.org/salary/business-development-sales-executive/Gurgaon?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Jooble', 'salary_from': 4.1, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Presentation Specialist', 'link': 'https://www.ambitionbox.com/salaries/clifford-chance-salaries/presentation-specialist?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'AmbitionBox', 'salary_from': 6, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"
#
# <class 'str'> "[{'job_title': 'Devops Engineer', 'link': 'https://www.glassdoor.com/Salaries/gurgaon-devops-engineer-salary-SRCH_IL.0,7_IC2921225_KO8,23.htm?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Glassdoor', 'salary_from': 6.5, 'salary_to': 15, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Development Operations (DevOps) Engineer', 'link': 'https://www.payscale.com/research/IN/Job=Development_Operations_(DevOps)_Engineer/Salary/9634b130/Gurgaon?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'Payscale', 'salary_from': 3.3, 'salary_to': 25, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}, {'job_title': 'Senior Devops Engineer', 'link': 'https://www.ambitionbox.com/salaries/espire-infolabs-salaries/senior-devops-engineer/new-delhi-location?utm_campaign=google_jobs_salary&utm_source=google_jobs_salary&utm_medium=organic', 'source': 'AmbitionBox', 'salary_from': 12, 'salary_to': 13, 'salary_periodicity': 'year', 'salary_period': 'year', 'based_on': 'Based on local employers'}]"

# %%
import csv

# Read the improperly formatted CSV data
with open('salaries.csv', 'r') as infile:
    reader = csv.reader(infile)
    rows = list(reader)

# Write the corrected CSV data
with open('salaries_corrected.csv', 'w', newline='') as outfile:
    writer = csv.writer(outfile, quoting=csv.QUOTE_MINIMAL)

    # Write the header
    writer.writerow([
        'job_title', 'link', 'source', 'salary_from', 'salary_to',
        'salary_currency', 'salary_periodicity', 'salary_period', 'based_on'
    ])

    for row in rows:
        # Enclose text fields with double quotes to handle commas within the text
        job_title = row[0]
        link = row[1]
        source = row[2]
        salary_from = row[3]
        salary_to = row[4] if len(row) > 4 else ''
        salary_currency = row[5] if len(row) > 5 else ''
        salary_periodicity = row[6] if len(row) > 6 else ''
        salary_period = row[7] if len(row) > 7 else ''
        based_on = row[8] if len(row) > 8 else ''

        # Write the corrected row
        writer.writerow([
            job_title, link, source, salary_from, salary_to,
            salary_currency, salary_periodicity, salary_period, based_on
        ])

# %%
import pandas as pd
df = pd.read_csv('salaries_corrected.csv')
df.head()
# Out:
#                                   job_title  \
# 0  'job_title': 'External Relations Intern'
# 1    'job_title': 'Director of Development'
# 2     'job_title': 'Director of Development
# 3     'job_title': 'Director of Development
# 4   'job_title': ""Women's Health Manager""
#
#                                                 link  \
# 0   'link': 'https://www.glassdoor.com/Salary/Int...
# 1   'link': 'https://www.glassdoor.com/Salaries/n...
# 2                           Non-Profit Organization'
# 3                           Non-Profit Organization'
# 4   'link': ""https://www.indeed.com/cmp/Hire-Par...
#
#                                               source  \
# 0  71.htm?utm_campaign=google_jobs_salary&utm_sou...
# 1                                      13_IM615_KO14
# 2   'link': 'https://www.salary.com/research/sala...
# 3   'link': 'https://www.payscale.com/research/US...
# 4  -LLC/salaries/Women's-Health-Manager/Massachus...
#
#                                          salary_from               salary_to  \
# 0                              'source': 'Glassdoor'    'salary_from': 40000
# 1  37.htm?utm_campaign=google_jobs_salary&utm_sou...   'source': 'Glassdoor'
# 2                             'source': 'Salary.com'      'salary_from': 1.1
# 3                               'source': 'Payscale'    'salary_from': 58000
# 4                                 'source': 'Indeed'    'salary_from': 55000
#
#            salary_currency             salary_periodicity  \
# 0       'salary_to': 60000         'salary_currency': '$'
# 1       'salary_from': 1.5               'salary_to': 2.6
# 2         'salary_to': 2.7         'salary_currency': '$'
# 3         'salary_to': 1.4         'salary_currency': '$'
# 4   'salary_currency': '$'   'salary_periodicity': 'year'
#
#                    salary_period                                 based_on
# 0   'salary_periodicity': 'year'                  'salary_period': 'year'
# 1         'salary_currency': '$'             'salary_periodicity': 'year'
# 2   'salary_periodicity': 'year'                  'salary_period': 'year'
# 3   'salary_periodicity': 'year'                  'salary_period': 'year'
# 4        'salary_period': 'year'   'based_on': 'Based on local employers'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_title           87 non-null     object
#  1   link                87 non-null     object
#  2   source              87 non-null     object
#  3   salary_from         87 non-null     object
#  4   salary_to           87 non-null     object
#  5   salary_currency     87 non-null     object
#  6   salary_periodicity  87 non-null     object
#  7   salary_period       80 non-null     object
#  8   based_on            58 non-null     object
# dtypes: object(9)
# memory usage: 6.2+ KB
